# %% [markdown]
# # 🏢 Invoice Processing with LangGraph + LangChain
# ## Automated Invoice Classification using LangChain Document Processing
#
# ### 🎯 Use Case: Accounts Payable Automation
# Automatically classify incoming invoices to streamline payment processing:
# - ✅ **Valid**: Complete invoice ready for payment
# - ❌ **Invalid**: Rejected invoice requiring vendor correction
#
# ### 🛠️ Technology Stack
# - **LangGraph**: Workflow orchestration
# - **LangChain**: Document loading and text splitting
# - **OpenAI**: Embeddings and GPT-4 classification
# - **Pinecone**: Vector storage for RAG
#
# ### 📋 Business Rules
# **Valid Invoice Requirements:**
# - All invoices must include vendor name, invoice number, date, and amount
# - Missing any required field = Invalid classification
#
# ### 🔄 Workflow: PDF -> LLM -> Markdown -> Vector DB

# %%
# !pip install langchain-openai langchain-google-genai PyMuPDF
# Out:
# Requirement already satisfied: langchain-openai in d:\projects\evidence-auditor\.venv\lib\site-packages (0.3.35)
# Requirement already satisfied: langchain-google-genai in d:\projects\evidence-auditor\.venv\lib\site-packages (2.1.12)
# Requirement already satisfied: PyMuPDF in d:\projects\evidence-auditor\.venv\lib\site-packages (1.26.4)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.78 in d:\projects\evidence-auditor\.venv\lib\site-packages (from langchain-openai) (0.3.78)
# Requirement already satisfied: openai<3.0.0,>=1.104.2 in d:\projects\evidence-auditor\.venv\lib\site-packages (from langchain-openai) (2.2.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in d:\projects\evidence-auditor\.venv\lib\site-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in d:\projects\evidence-auditor\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.78->langchain-openai) (0.4.32)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\projects\evidence-auditor\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.78->langchain-openai) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in d:\projects\evidence-auditor\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.78->langchain-openai) (1.33)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in d:\projects\evidence-auditor\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.78->langchain-openai) (6.0.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in d:\projects\evidence-auditor\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.78->langchain-openai) (4.15.0)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in d:\projects\evidence-auditor\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.78->langchain-openai) (24.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in d:\projects\evidence-auditor\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.78->langchain-openai) (2.11.10)
# Requirement already satisfied: jsonpointer>=1.9 in d:\projects\evidence-auditor\.venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<1.0.0,>=0.3.78->langchain-openai) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\projects\evidence-auditor\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain-openai) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in d:\projects\evidence-auditor\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain-openai) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in d:\projects\evidence-auditor\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain-openai) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in d:\projects\evidence-auditor\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain-openai) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in d:\projects\evidence-auditor\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain-openai) (0.25.0)
# Requirement already satisfied: anyio in d:\projects\evidence-auditor\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain-openai) (4.11.0)
# Requirement already satisfied: certifi in d:\projects\evidence-auditor\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain-openai) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in d:\projects\evidence-auditor\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain-openai) (1.0.9)
# Requirement already satisfied: idna in d:\projects\evidence-auditor\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain-openai) (3.10)
# Requirement already satisfied: h11>=0.16 in d:\projects\evidence-auditor\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain-openai) (0.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in d:\projects\evidence-auditor\.venv\lib\site-packages (from openai<3.0.0,>=1.104.2->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in d:\projects\evidence-auditor\.venv\lib\site-packages (from openai<3.0.0,>=1.104.2->langchain-openai) (0.11.0)
# Requirement already satisfied: sniffio in d:\projects\evidence-auditor\.venv\lib\site-packages (from openai<3.0.0,>=1.104.2->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in d:\projects\evidence-auditor\.venv\lib\site-packages (from openai<3.0.0,>=1.104.2->langchain-openai) (4.67.1)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\projects\evidence-auditor\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.78->langchain-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in d:\projects\evidence-auditor\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.78->langchain-openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in d:\projects\evidence-auditor\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.78->langchain-openai) (0.4.2)
# Requirement already satisfied: regex>=2022.1.18 in d:\projects\evidence-auditor\.venv\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2025.9.18)
# Requirement already satisfied: google-ai-generativelanguage<1,>=0.7 in d:\projects\evidence-auditor\.venv\lib\site-packages (from langchain-google-genai) (0.7.0)
# Requirement already satisfied: filetype<2,>=1.2 in d:\projects\evidence-auditor\.venv\lib\site-packages (from langchain-google-genai) (1.2.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 in d:\projects\evidence-auditor\.venv\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1,>=0.7->langchain-google-genai) (2.25.2)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 in d:\projects\evidence-auditor\.venv\lib\site-packages (from google-ai-generativelanguage<1,>=0.7->langchain-google-genai) (2.41.1)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in d:\projects\evidence-auditor\.venv\lib\site-packages (from google-ai-generativelanguage<1,>=0.7->langchain-google-genai) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in d:\projects\evidence-auditor\.venv\lib\site-packages (from google-ai-generativelanguage<1,>=0.7->langchain-google-genai) (6.32.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in d:\projects\evidence-auditor\.venv\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1,>=0.7->langchain-google-genai) (1.70.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in d:\projects\evidence-auditor\.venv\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1,>=0.7->langchain-google-genai) (1.75.1)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in d:\projects\evidence-auditor\.venv\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1,>=0.7->langchain-google-genai) (1.75.1)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in d:\projects\evidence-auditor\.venv\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1,>=0.7->langchain-google-genai) (6.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\projects\evidence-auditor\.venv\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1,>=0.7->langchain-google-genai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\projects\evidence-auditor\.venv\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1,>=0.7->langchain-google-genai) (4.9.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\projects\evidence-auditor\.venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain-openai) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\projects\evidence-auditor\.venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain-openai) (2.5.0)
# Requirement already satisfied: pyasn1>=0.1.3 in d:\projects\evidence-auditor\.venv\lib\site-packages (from rsa<5,>=3.1.4->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1,>=0.7->langchain-google-genai) (0.6.1)
# Requirement already satisfied: colorama in d:\projects\evidence-auditor\.venv\lib\site-packages (from tqdm>4->openai<3.0.0,>=1.104.2->langchain-openai) (0.4.6)

# %%
import os
import base64
from pathlib import Path
import getpass
import fitz  # PyMuPDF
from langchain_openai import ChatOpenAI
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import HumanMessage

# Configuration
DATA_DIR = "data"
OUTPUT_DIR = "markdown_output"
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY") or getpass.getpass("OpenAI API Key: ")
GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY") or getpass.getpass("Google API Key: ")

# Create output directory
Path(OUTPUT_DIR).mkdir(exist_ok=True)

print("✅ Setup complete!")
# Out:
# ✅ Setup complete!

# %%
# Initialize LLM
# OpenAI option:
# llm = ChatOpenAI(
#     api_key=OPENAI_API_KEY,
#     model="gpt-4o-mini",
#     temperature=0
# )

# Google Gemini option:
llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    google_api_key=GOOGLE_API_KEY,
    temperature=0
)

def pdf_to_base64(pdf_path: str) -> str:
    """Convert first page of PDF to base64 image"""
    doc = fitz.open(pdf_path)
    page = doc.load_page(0)
    pix = page.get_pixmap(matrix=fitz.Matrix(2, 2))
    img_data = pix.tobytes("png")
    doc.close()
    return base64.b64encode(img_data).decode()

def pdf_to_markdown(pdf_path: str) -> str:
    """Convert PDF to markdown using LLM vision"""
    image_base64 = pdf_to_base64(pdf_path)
    
    message = HumanMessage(
        content=[
            {
                "type": "text",
                "text": "Convert this document to clean markdown format. Preserve structure, headings, and content. Return only the markdown."
            },
            {
                "type": "image_url",
                "image_url": {"url": f"data:image/png;base64,{image_base64}"}
            }
        ]
    )
    
    response = llm.invoke([message])
    return response.content.strip()

print("✅ Functions ready!")
# Out:
# ✅ Functions ready!

# %%
# Process all PDFs
data_dir = Path(DATA_DIR)
pdf_files = list(data_dir.glob("*.pdf"))

print(f"📁 Found {len(pdf_files)} PDF files")

for pdf_file in pdf_files:
    print(f"\n📄 Processing: {pdf_file.name}")
    
    try:
        # Convert to markdown
        markdown_content = pdf_to_markdown(str(pdf_file))
        
        # Save as .md file
        output_file = Path(OUTPUT_DIR) / f"{pdf_file.stem}.md"
        with open(output_file, 'w', encoding='utf-8') as f:
            f.write(markdown_content)
        
        print(f"✅ Saved: {output_file}")
        print(f"📊 Size: {len(markdown_content)} characters")
        
    except Exception as e:
        print(f"❌ Error: {e}")

print(f"\n✅ Complete! Check {OUTPUT_DIR}/ for markdown files")
# Out:
# 📁 Found 6 PDF files
#
# 📄 Processing: invoice_1.pdf
# ✅ Saved: markdown_output\invoice_1.md
# 📊 Size: 875 characters
#
# 📄 Processing: invoice_2.pdf
# ✅ Saved: markdown_output\invoice_2.md
# 📊 Size: 1060 characters
#
# 📄 Processing: invoice_3.pdf
# ✅ Saved: markdown_output\invoice_3.md
# 📊 Size: 1521 characters
#
# 📄 Processing: invoice_4.pdf
# ✅ Saved: markdown_output\invoice_4.md
# 📊 Size: 1408 characters
#
# 📄 Processing: invoice_5.pdf
# ✅ Saved: markdown_output\invoice_5.md
# 📊 Size: 1308 characters
#
# 📄 Processing: invoice_6.pdf
# ✅ Saved: markdown_output\invoice_6.md
# 📊 Size: 1018 characters
#
# ✅ Complete! Check markdown_output/ for markdown files

# %%
# Load markdown files to vector database
# !pip install langchain-pinecone pinecone

from langchain_openai import OpenAIEmbeddings
from langchain_google_genai import GoogleGenerativeAIEmbeddings
from langchain_pinecone import PineconeVectorStore
from langchain.schema import Document
from pinecone import Pinecone, ServerlessSpec

# Initialize components
embeddings = GoogleGenerativeAIEmbeddings(api_key=GOOGLE_API_KEY, model="gemini-embedding-001")
PINECONE_API_KEY = os.getenv("PINECONE_API_KEY") or getpass.getpass("Pinecone API Key: ")
INDEX_NAME = "pdf-markdown-vectors"

pc = Pinecone(api_key=PINECONE_API_KEY)

# Create index if needed
existing = [idx["name"] for idx in pc.list_indexes()]
if INDEX_NAME not in existing:
    pc.create_index(
        name=INDEX_NAME,
        dimension=3072,
        metric="cosine",
        spec=ServerlessSpec(cloud="aws", region="us-east-1")
    )
    import time
    time.sleep(10)

index = pc.Index(INDEX_NAME)
vector_store = PineconeVectorStore(index=index, embedding=embeddings)

# Load markdown files
output_dir = Path(OUTPUT_DIR)
md_files = list(output_dir.glob("*.md"))

documents = []
for md_file in md_files:
    with open(md_file, 'r', encoding='utf-8') as f:
        content = f.read()
    
    doc = Document(
        page_content=content,
        metadata={
            'pdf_filename': f"{md_file.stem}.pdf",
            'markdown_filename': md_file.name,
            'doc_type': 'pdf_markdown'
        }
    )
    documents.append(doc)

# Store in vector database
if documents:
    vector_ids = vector_store.add_documents(documents)
    print(f"✅ Stored {len(vector_ids)} documents in Pinecone")
    
    # Test search
    results = vector_store.similarity_search("invoice amount", k=2)
    for i, doc in enumerate(results, 1):
        pdf_name = doc.metadata.get('pdf_filename', 'Unknown')
        print(f"{i}. {pdf_name}: {doc.page_content[:100]}...")
else:
    print("❌ No documents to store")
# Out:
# Requirement already satisfied: langchain-pinecone in d:\projects\evidence-auditor\.venv\lib\site-packages (0.2.12)
# Requirement already satisfied: pinecone in d:\projects\evidence-auditor\.venv\lib\site-packages (7.3.0)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.34 in d:\projects\evidence-auditor\.venv\lib\site-packages (from langchain-pinecone) (0.3.78)
# Requirement already satisfied: numpy>=1.26.4 in d:\projects\evidence-auditor\.venv\lib\site-packages (from langchain-pinecone) (2.3.3)
# Requirement already satisfied: langchain-openai>=0.3.11 in d:\projects\evidence-auditor\.venv\lib\site-packages (from langchain-pinecone) (0.3.35)
# Requirement already satisfied: httpx>=0.28.0 in d:\projects\evidence-auditor\.venv\lib\site-packages (from langchain-pinecone) (0.28.1)
# Requirement already satisfied: simsimd>=5.9.11 in d:\projects\evidence-auditor\.venv\lib\site-packages (from langchain-pinecone) (6.5.3)
# Requirement already satisfied: certifi>=2019.11.17 in d:\projects\evidence-auditor\.venv\lib\site-packages (from pinecone) (2025.10.5)
# Requirement already satisfied: pinecone-plugin-assistant<2.0.0,>=1.6.0 in d:\projects\evidence-auditor\.venv\lib\site-packages (from pinecone) (1.8.0)
# Requirement already satisfied: pinecone-plugin-interface<0.0.8,>=0.0.7 in d:\projects\evidence-auditor\.venv\lib\site-packages (from pinecone) (0.0.7)
# Requirement already satisfied: python-dateutil>=2.5.3 in d:\projects\evidence-auditor\.venv\lib\site-packages (from pinecone) (2.9.0.post0)
# Requirement already satisfied: typing-extensions>=3.7.4 in d:\projects\evidence-auditor\.venv\lib\site-packages (from pinecone) (4.15.0)
# Requirement already satisfied: urllib3>=1.26.5 in d:\projects\evidence-auditor\.venv\lib\site-packages (from pinecone) (2.5.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in d:\projects\evidence-auditor\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.34->langchain-pinecone) (0.4.32)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\projects\evidence-auditor\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.34->langchain-pinecone) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in d:\projects\evidence-auditor\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.34->langchain-pinecone) (1.33)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in d:\projects\evidence-auditor\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.34->langchain-pinecone) (6.0.3)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in d:\projects\evidence-auditor\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.34->langchain-pinecone) (24.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in d:\projects\evidence-auditor\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.34->langchain-pinecone) (2.11.10)
# Requirement already satisfied: jsonpointer>=1.9 in d:\projects\evidence-auditor\.venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<1.0.0,>=0.3.34->langchain-pinecone) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in d:\projects\evidence-auditor\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.34->langchain-pinecone) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in d:\projects\evidence-auditor\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.34->langchain-pinecone) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in d:\projects\evidence-auditor\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.34->langchain-pinecone) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in d:\projects\evidence-auditor\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.34->langchain-pinecone) (0.25.0)
# Requirement already satisfied: anyio in d:\projects\evidence-auditor\.venv\lib\site-packages (from httpx>=0.28.0->langchain-pinecone) (4.11.0)
# Requirement already satisfied: httpcore==1.* in d:\projects\evidence-auditor\.venv\lib\site-packages (from httpx>=0.28.0->langchain-pinecone) (1.0.9)
# Requirement already satisfied: idna in d:\projects\evidence-auditor\.venv\lib\site-packages (from httpx>=0.28.0->langchain-pinecone) (3.10)
# Requirement already satisfied: h11>=0.16 in d:\projects\evidence-auditor\.venv\lib\site-packages (from httpcore==1.*->httpx>=0.28.0->langchain-pinecone) (0.16.0)
# Requirement already satisfied: aiohttp>=3.9.0 in d:\projects\evidence-auditor\.venv\lib\site-packages (from pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (3.13.0)
# Requirement already satisfied: aiohttp-retry<3.0.0,>=2.9.1 in d:\projects\evidence-auditor\.venv\lib\site-packages (from pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (2.9.1)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\projects\evidence-auditor\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.34->langchain-pinecone) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in d:\projects\evidence-auditor\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.34->langchain-pinecone) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in d:\projects\evidence-auditor\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.34->langchain-pinecone) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\projects\evidence-auditor\.venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.34->langchain-pinecone) (3.4.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in d:\projects\evidence-auditor\.venv\lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in d:\projects\evidence-auditor\.venv\lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in d:\projects\evidence-auditor\.venv\lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\projects\evidence-auditor\.venv\lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\projects\evidence-auditor\.venv\lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in d:\projects\evidence-auditor\.venv\lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (0.4.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in d:\projects\evidence-auditor\.venv\lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (1.22.0)
# Requirement already satisfied: openai<3.0.0,>=1.104.2 in d:\projects\evidence-auditor\.venv\lib\site-packages (from langchain-openai>=0.3.11->langchain-pinecone) (2.2.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in d:\projects\evidence-auditor\.venv\lib\site-packages (from langchain-openai>=0.3.11->langchain-pinecone) (0.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in d:\projects\evidence-auditor\.venv\lib\site-packages (from openai<3.0.0,>=1.104.2->langchain-openai>=0.3.11->langchain-pinecone) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in d:\projects\evidence-auditor\.venv\lib\site-packages (from openai<3.0.0,>=1.104.2->langchain-openai>=0.3.11->langchain-pinecone) (0.11.0)
# Requirement already satisfied: sniffio in d:\projects\evidence-auditor\.venv\lib\site-packages (from openai<3.0.0,>=1.104.2->langchain-openai>=0.3.11->langchain-pinecone) (1.3.1)
# Requirement already satisfied: tqdm>4 in d:\projects\evidence-auditor\.venv\lib\site-packages (from openai<3.0.0,>=1.104.2->langchain-openai>=0.3.11->langchain-pinecone) (4.67.1)
# Requirement already satisfied: regex>=2022.1.18 in d:\projects\evidence-auditor\.venv\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai>=0.3.11->langchain-pinecone) (2025.9.18)
# Requirement already satisfied: six>=1.5 in d:\projects\evidence-auditor\.venv\lib\site-packages (from python-dateutil>=2.5.3->pinecone) (1.17.0)
# Requirement already satisfied: colorama in d:\projects\evidence-auditor\.venv\lib\site-packages (from tqdm>4->openai<3.0.0,>=1.104.2->langchain-openai>=0.3.11->langchain-pinecone) (0.4.6)
# ✅ Stored 6 documents in Pinecone
