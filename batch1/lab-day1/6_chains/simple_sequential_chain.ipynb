# %%
# !pip install -qU langchain-groq langchain

# %%
import os
#from langchain_openai import ChatOpenAI
from langchain_groq import ChatGroq
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnableLambda
from google.colab import userdata

os.environ["GROQ_API_KEY"] = userdata.get('GROQ_API_KEY')

#llm=ChatOpenAI(model="gpt-4o", temperature=0.1, max_retries=3)
# Initialize the Groq model
llm = ChatGroq(
    model="llama-3.1-8b-instant",
    temperature=0,
    max_retries=2,
)

title_prompt = PromptTemplate(
    input_variables=["topic"],
    template="""You are an experienced speech writer.
    You need to craft an impactful title for a speech
    on the following topic: {topic}
    Answer exactly with one title.
    """
)

speech_prompt = PromptTemplate(
    input_variables=["title"],
    template="""You need to write a powerful speech of 350 words
     for the following title: {title}
    """
)

# A function to print the intermediate output and pass it along
def log_title(title):
    print("--- Generated Title ---")
    print(title)
    print("-----------------------")
    return title

first_chain = title_prompt | llm | StrOutputParser() | RunnableLambda(log_title)
second_chain = speech_prompt | llm
final_chain = first_chain | second_chain

topic = "The impact of AI on modern education"
response = final_chain.invoke({"topic":topic})
print(response.content)
# Out:
# --- Generated Title ---
# "Rethinking the Classroom: The Revolution of AI in Modern Education"
# -----------------------
# Ladies and gentlemen, esteemed educators, and fellow visionaries, I stand before you today to ignite a conversation that will redefine the very fabric of our educational system. The classroom, once a static and traditional space, is on the cusp of a revolution. Artificial Intelligence (AI) is no longer a distant dream, but a tangible reality that is poised to transform the way we learn, teach, and interact.
#
# For too long, our classrooms have been bound by the constraints of outdated methods and limited resources. But AI is here to shatter these barriers, unleashing a new era of personalized learning, adaptive assessments, and immersive experiences. With AI, every student can receive tailored instruction, tailored to their unique learning style, pace, and abilities.
#
# Imagine a classroom where AI-powered tools assist teachers in identifying knowledge gaps, predicting student performance, and providing real-time feedback. Where AI-driven simulations and virtual labs bring complex concepts to life, making learning more engaging and interactive. Where AI-facilitated discussions and debates foster critical thinking, creativity, and collaboration.
#
# But this revolution is not just about technology; it's about people. It's about empowering teachers to focus on what matters most – nurturing the minds, hearts, and souls of their students. AI can help alleviate the administrative burden, freeing educators to concentrate on the art of teaching, not just the science of instruction.
#
# We must rethink the classroom, not just as a physical space, but as a dynamic, adaptive, and inclusive environment that caters to the diverse needs of our students. We must harness the power of AI to create a more equitable, accessible, and effective education system.
#
# The future of education is not a prediction; it's a possibility. And it's up to us to seize this moment, to harness the potential of AI, and to create a new paradigm for learning. Let us embark on this journey together, with courage, curiosity, and a commitment to revolutionizing the classroom. The future of education is waiting for us.
