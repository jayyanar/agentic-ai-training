# %%
#!pip install -qU langchain-ollama

# %%
from langchain_ollama import ChatOllama

#model_name = "qwen3"
model_name = "gemma3"
llm = ChatOllama(
    model=model_name,
    temperature=0,
)

# %%
messages = [
    (
        "system",
        "You are a helpful assistant that translates English to French. Translate the user sentence.",
    ),
    ("human", "I love programming."),
]
ai_msg = llm.invoke(messages)
ai_msg
# Out:
# AIMessage(content='Je suis passionné(e) par la programmation. \n\n(Note: Use "passionné" if you are male, "passionnée" if you are female.)\n\nAlternatively, you could also say:\n\nJ\'adore la programmation. \n\nWould you like me to translate something else?', additional_kwargs={}, response_metadata={'model': 'gemma3', 'created_at': '2025-10-06T17:32:46.012788Z', 'done': True, 'done_reason': 'stop', 'total_duration': 6049283000, 'load_duration': 4847838750, 'prompt_eval_count': 34, 'prompt_eval_duration': 272633084, 'eval_count': 64, 'eval_duration': 898778125, 'model_name': 'gemma3'}, id='run--13136612-2121-495e-a231-4c9561ca32c2-0', usage_metadata={'input_tokens': 34, 'output_tokens': 64, 'total_tokens': 98})

# %%
print(ai_msg.content)
# Out:
# Je suis passionné(e) par la programmation.
#
# (Note: Use "passionné" if you are male, "passionnée" if you are female.)
#
# Alternatively, you could also say:
#
# J'adore la programmation.
#
# Would you like me to translate something else?

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "You are a helpful assistant that translates {input_language} to {output_language}. Give just the translated sentence, do not include any other text.",
        ),
        ("human", "{input}"),
    ]
)

chain = prompt | llm
msg = chain.invoke(
    {
        "input_language": "English",
        "output_language": "German",
        "input": "I love programming.",
    }
)
print(msg.content)
# Out:
# Ich liebe das Programmieren.
